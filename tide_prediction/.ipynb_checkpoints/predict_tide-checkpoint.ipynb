# %% [markdown]
# # Use Fourier analysis to predict the tide
#
# Data (Calliaqua, St Vincent and the Grenadines, hourly) downloaded from here:
#     https://psmsl.org/cme/downloaddata.php
#
# Use first half of data to do Fourier analysis.
# Use the remaining data as validation

# %%
import pandas as pd
import math
import cmath
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
import mpld3
mpld3.enable_notebook()

def load_tide_data(f):
    # use Pandas to read data and then convert to a numpy array
    d = pd.read_csv(f, header=None).to_numpy()
    return d

def fourier_coeff(w, d):
    d = d.flatten()
    T = np.array(list(range(0, d.shape[0])))
    e = np.exp(np.multiply(T, 1j*w*2*math.pi))
    fourier_a_b = sum(np.multiply(e, d)) / d.shape[0]
    
    # return fourier_integral.real, fourier_integral.imag
    return fourier_a_b

def main():
    d = load_tide_data('calq_rad_processed.csv')
    find_cycle(d, 10)
    d_mean = np.mean(d)
    d = d - d_mean
    
    N = d.shape[0]
    N_train = math.ceil(N/2) # Training data index
    
    
    N_train = 6531 ################
    
    N_vali = N_train * 2
    d_train = d[0:N_train]
    d_vali = d[0:N_vali]
    print("N_train=", N_train, "N_vali=", N_vali)
    T = np.array(list(range(0, d_vali.shape[0])))
    
    # d_train = np.sin(T*0.21349 - 0.5) ################
    
    w = np.arange(1, d_train.shape[0]+1, 1) / d_train.shape[0]
    print("T.shape = ", T.shape, "w.shape = ", w.shape)
    F = np.full(w.shape[0], 0j)
    d_predict = 0 * d_vali.flatten()
    terms_count = 0
    for k in range(0, w.shape[0]):
        F[k] = fourier_coeff(w[k], d_train)
        if (np.abs(F[k]) > -0.001):
            # print("k=", k, ", w[", k, "]=", w[k], ", F[", k, "]=", F[k])
            d_predict = d_predict + F[k].real * np.cos(T*w[k]*2*np.pi)
            d_predict = d_predict + F[k].imag * np.sin(T*w[k]*2*np.pi)
            terms_count = terms_count + 1
    
    print(terms_count, "out of", w.shape[0], "terms of Fourier series are used.")
    # print("w[20] = ", w[20], "w[40] = ", w[40])
    plt.plot(d_train, '*')
    plt.plot(d_vali, '.')
    plt.plot(d_predict)
    plt.ylabel('Train data vs Fourier Series')
    plt.show()
    
    plt.plot(np.abs(F))
    plt.ylabel('Magnitude of F')
    plt.show()
    
    plt.plot(F.real)
    plt.plot(F.imag)
    plt.ylabel('Real and Imag of F')
    plt.show()

def find_cycle(d, N):
    cycle_flag = 0
    for m in range(N, d.shape[0]-N):
        # print("in for loop, m=", m, "d[m]=", d[m])
        n = 0
        while abs(d[n] - d[m+n]) < 0.03 and n < N:
            n = n + 1
        if n == N:
            cycle_flag = 1
            break
    print("at d[", m, "]=", d[m], ", it's the cycle")
    
if __name__ == "__main__":
    main()
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\kernel\__init__.py:12: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   warn("The `IPython.kernel` package has been deprecated since IPython 4.0."
# WARNING: AstropyDeprecationWarning: The private astropy._erfa module has been made into its own package, pyerfa, which is a dependency of astropy and can be imported directly using "import erfa" [astropy._erfa]
# C:\ProgramData\Anaconda3\lib\pkgutil.py:92: MatplotlibDeprecationWarning:
# The matplotlib.compat module was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   __import__(info.name)
# C:\ProgramData\Anaconda3\lib\site-packages\nltk\twitter\__init__.py:21: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\skimage\viewer\utils\__init__.py:1: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   from .core import *
# C:\ProgramData\Anaconda3\lib\site-packages\qtawesome\iconic_font.py:313: UserWarning: You need to have a running QApplication to use QtAwesome!
#   warnings.warn("You need to have a running "
# C:\ProgramData\Anaconda3\lib\pkgutil.py:107: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   yield from walk_packages(path, info.name+'.', onerror)
# Cython              brain_re            mailbox             smtplib
# IPython             brain_responses     mailcap             sndhdr
# OpenSSL             brain_scipy_signal  markupsafe          sniffio
# PIL                 brain_six           marshal             snowballstemmer
# PyQt5               brain_sqlalchemy    math                socket
# __future__          brain_ssl           matplotlib          socketserver
# _abc                brain_subprocess    mccabe              socks
# _ast                brain_threading     menuinst            sockshandler
# _asyncio            brain_type          mimetypes           sortedcollections
# _bisect             brain_typing        mistune             sortedcontainers
# _black_version      brain_uuid          mkl                 soupsieve
# _blake2             brotli              mkl_fft             sphinx
# _bootlocale         bs4                 mkl_random          sphinxcontrib
# _bz2                builtins            mmap                spyder
# _cffi_backend       bz2                 mmapfile            spyder_kernels
# _codecs             cProfile            mmsystem            sqlalchemy
# _codecs_cn          calendar            mock                sqlite3
# _codecs_hk          certifi             modulefinder        sre_compile
# _codecs_iso2022     cffi                more_itertools      sre_constants
# _codecs_jp          cgi                 mpld3               sre_parse
# _codecs_kr          cgitb               mpmath              ssl
# _codecs_tw          chardet             msgpack             sspi
# _collections        chunk               msilib              sspicon
# _collections_abc    click               msvcrt              stat
# _compat_pickle      cloudpickle         multipledispatch    statistics
# _compression        clyent              multiprocessing     statsmodels
# _contextvars        cmath               mypy_extensions     storemagic
# _csv                cmd                 nacl                string
# _ctypes             code                navigator_updater   stringprep
# _ctypes_test        codecs              nbclassic           struct
# _datetime           codeop              nbclient            subprocess
# _decimal            collections         nbconvert           sunau
# _distutils_hack     colorama            nbformat            symbol
# _dummy_thread       colorsys            nest_asyncio        sympy
# _elementtree        commctrl            netbios             sympyprinting
# _functools          compileall          netrc               symtable
# _hashlib            comtypes            networkx            sys
# _heapq              concurrent          nltk                sysconfig
# _imp                conda               nntplib             tables
# _io                 conda_build         nose                tabnanny
# _json               conda_content_trust notebook            tarfile
# _locale             conda_env           nt                  tblib
# _lsprof             conda_package_handling ntpath              telnetlib
# _lzma               conda_token         ntsecuritycon       tempfile
# _markupbase         conda_verify        nturl2path          terminado
# _md5                configparser        numba               test
# _msi                contextlib          numbers             test_pycosat
# _multibytecodec     contextlib2         numexpr             testpath
# _multiprocessing    contextvars         numpy               tests
# _nsis               copy                numpydoc            textdistance
# _opcode             copyreg             odbc                textwrap
# _operator           crypt               olefile             this
# _osx_support        cryptography        opcode              threading
# _overlapped         csv                 openpyxl            threadpoolctl
# _pickle             ctypes              operator            three_merge
# _py_abc             curl                optparse            tifffile
# _pydecimal          curses              os                  time
# _pyio               cwp                 packaging           timeit
# _pyrsistent_version cycler              pandas              timer
# _pytest             cython              pandocfilters       tkinter
# _queue              cythonmagic         paramiko            tlz
# _random             cytoolz             parser              token
# _sha1               dask                parso               tokenize
# _sha256             dataclasses         partd               toml
# _sha3               datetime            past                toolz
# _sha512             dateutil            path                tornado
# _signal             dbi                 pathlib             tqdm
# _sitebuiltins       dbm                 pathlib2            trace
# _socket             dde                 pathspec            traceback
# _sqlite3            decimal             patsy               tracemalloc
# _sre                decorator           pdb                 traitlets
# _ssl                defusedxml          pep8                tty
# _stat               diff_match_patch    perfmon             turtle
# _statistics         difflib             pexpect             turtledemo
# _string             dis                 pickle              typed_ast
# _strptime           distributed         pickleshare         types
# _struct             distutils           pickletools         typing
# _symtable           doctest             pip                 typing_extensions
# _system_path        docutils            pipes               ujson
# _testbuffer         dummy_threading     pkg_resources       unicodecsv
# _testcapi           email               pkginfo             unicodedata
# _testconsole        encodings           pkgutil             unittest
# _testimportmultiple ensurepip           platform            urllib
# _testinternalcapi   entrypoints         plistlib            urllib3
# _testmultiphase     enum                pluggy              uu
# _thread             erfa                ply                 uuid
# _threading_local    errno               poplib              venv
# _tkinter            et_xmlfile          posixpath           warnings
# _tracemalloc        fastcache           pprint              watchdog
# _warnings           faulthandler        predict_tide        wave
# _weakref            filecmp             profile             wcwidth
# _weakrefset         fileinput           prometheus_client   weakref
# _win32sysloader     filelock            prompt_toolkit      webbrowser
# _winapi             flake8              pstats              webencodings
# _winxptheme         flask               psutil              werkzeug
# _xxsubinterpreters  fnmatch             pty                 wheel
# _yaml               formatter           ptyprocess          widgetsnbextension
# abc                 fractions           pvectorc            win2kras
# adodbapi            fsspec              py                  win32api
# afxres              ftplib              py_compile          win32clipboard
# aifc                functools           pyclbr              win32com
# alabaster           future              pycodestyle         win32con
# anaconda_navigator  gc                  pycosat             win32console
# anaconda_project    genericpath         pycparser           win32cred
# antigravity         getopt              pycurl              win32crypt
# anyio               getpass             pydoc               win32cryptcon
# appdirs             gettext             pydoc_data          win32ctypes
# argh                gevent              pydocstyle          win32event
# argon2              glob                pyexpat             win32evtlog
# argparse            glob2               pyflakes            win32evtlogutil
# array               greenlet            pygments            win32file
# asn1crypto          gzip                pylab               win32gui
# ast                 h5py                pylint              win32gui_struct
# astroid             hashlib             pyls                win32help
# astropy             heapdict            pyls_black          win32inet
# async_generator     heapq               pyls_jsonrpc        win32inetcon
# asynchat            hmac                pyls_spyder         win32job
# asyncio             html                pyodbc              win32lz
# asyncore            html5lib            pyparsing           win32net
# atexit              http                pyreadline          win32netcon
# atomicwrites        idlelib             pyrsistent          win32pdh
# attr                idna                pytest              win32pdhquery
# audioop             imagecodecs         pythoncom           win32pdhutil
# autopep8            imageio             pytz                win32pipe
# autoreload          imagesize           pywin               win32print
# babel               imaplib             pywin32_bootstrap   win32process
# backcall            imghdr              pywin32_testutil    win32profile
# backports           imp                 pywintypes          win32ras
# base64              importlib           pywt                win32rcparser
# bcrypt              importlib_metadata  pyximport           win32security
# bdb                 iniconfig           qdarkstyle          win32service
# binascii            inspect             qtawesome           win32serviceutil
# binhex              intervaltree        qtconsole           win32timezone
# binstar_client      io                  qtpy                win32trace
# bisect              ipaddress           queue               win32traceutil
# bitarray            ipykernel           quopri              win32transaction
# bkcharts            ipykernel_launcher  random              win32ts
# black               ipython_genutils    rasutil             win32ui
# blackd              ipywidgets          re                  win32uiole
# bleach              isapi               readline            win32verstamp
# blib2to3            isort               regcheck            win32wnet
# bokeh               isympy              regex               win_inet_pton
# boto                itertools           regutil             win_unicode_console
# bottleneck          itsdangerous        repo_cli            wincertstore
# brain_argparse      jdcal               reprlib             winerror
# brain_attrs         jedi                requests            winioctlcon
# brain_boto3         jinja2              rlcompleter         winnt
# brain_builtin_inference joblib              rmagic              winperf
# brain_collections   json                rope                winpty
# brain_crypt         json5               rtree               winreg
# brain_curses        jsonschema          ruamel_yaml         winsound
# brain_dataclasses   jupyter             run                 winxpgui
# brain_dateutil      jupyter_client      runpy               winxptheme
# brain_fstrings      jupyter_console     sched               wrapt
# brain_functools     jupyter_core        scipy               wsgiref
# brain_gi            jupyter_packaging   scripts             xdrlib
# brain_hashlib       jupyter_server      seaborn             xlrd
# brain_http          jupyterlab          secrets             xlsxwriter
# brain_hypothesis    jupyterlab_pygments select              xlwings
# brain_io            jupyterlab_server   selectors           xlwt
# brain_mechanize     jupyterlab_widgets  send2trash          xml
# brain_multiprocessing keyring             servicemanager      xmlrpc
# brain_namedtuple_enum keyword             setuptools          xmltodict
# brain_nose          kiwisolver          shelve              xxsubtype
# brain_numpy_core_fromnumeric lazy_object_proxy   shlex               yaml
# brain_numpy_core_function_base lib2to3             shutil              yapf
# brain_numpy_core_multiarray libarchive          signal              yapftests
# brain_numpy_core_numeric libfuturize         simplegeneric       zict
# brain_numpy_core_numerictypes libpasteurize       singledispatch      zipapp
# brain_numpy_core_umath lief                sip                 zipfile
# brain_numpy_ndarray linecache           sipconfig           zipimport
# brain_numpy_random_mtrand llvmlite            sipdistutils        zipp
# brain_numpy_utils   locale              site                zlib
# brain_pkg_resources locket              six                 zmq
# brain_pytest        logging             skimage             zope
# brain_qt            lxml                sklearn
# brain_random        lzma                smtpd
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".
#
# at d[ 6532 ]= [0.579] , it's the cycle
# N_train= 6531 N_vali= 13062
# T.shape =  (13062,) w.shape =  (6531,)
